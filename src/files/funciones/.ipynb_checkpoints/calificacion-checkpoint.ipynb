# %%
import src.files.preguntas as qr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-91516f067a4c> in <module>
# ----> 1 import src.files.preguntas as qr
#
# ModuleNotFoundError: No module named 'src'

# %%
import src.files.funciones.calculo as calculo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7182fffbc20c> in <module>
# ----> 1 import src.files.funciones.calculo as calculo
#
# ModuleNotFoundError: No module named 'src'

# %%
# función con un parámetro
def calcularCalificaciondfInicial(df):
    # inicializar variables en 0 para que no guarden basura de pruebas anteriores
    cal_1 = 0
    cal_2 = 0
    cal_3 = 0
    cal_4 = 0
    cal_5 = 0
    cal_8 = 0
    lista = []
    # metodo para calcular las calificaciones, primera pregunta con su token , respuesta y calificacion asignada a la p1
    for i in range(len(df)):
        # print("prueba : ", qr.r1)
        # PrimeraPregunta
        if df[qr.r1][i] == qr.r1a:
            cal_1 = 1

        elif df[qr.r1][i] == qr.r1b:
            cal_1 = 2

        elif df[qr.r1][i] == qr.r1c:
            cal_1 = 3

        elif df[qr.r1][i] == qr.r1d:
            cal_1 = 4

        elif df[qr.r1][i] == qr.r1e:
            cal_1 = 5

        else:
            cal_1 = 0

        # Segunda pregunta
        if df[qr.r2][i] == qr.r2a:
            cal_2 = 1

        elif df[qr.r2][i] == qr.r2b:
            cal_2 = 2

        elif df[qr.r2][i] == qr.r2c:
            cal_2 = 3

        elif df[qr.r2][i] == qr.r2d:
            cal_2 = 4

        elif df[qr.r2][i] == qr.r2e:
            cal_2 = 5

        else:
            cal_2 = 0

        # Tercera pregunta
        if df[qr.r3][i] == qr.r3a:
            cal_3 = 1

        elif df[qr.r3][i] == qr.r3b:
            cal_3 = 2

        elif df[qr.r3][i] == qr.r3c:
            cal_3 = 3

        elif df[qr.r3][i] == qr.r3d:
            cal_3 = 4

        elif df[qr.r3][i] == qr.r3e:
            cal_3 = 5

        else:
            cal_3 = 0

        # 4ta pregunta
        if df[qr.r4][i] == qr.r4a:
            cal_4 = 1

        elif df[qr.r4][i] == qr.r4b:
            cal_4 = 2

        elif df[qr.r4][i] == qr.r4c:
            cal_4 = 3

        elif df[qr.r4][i] == qr.r4d:
            cal_4 = 4

        elif df[qr.r4][i] == qr.r4e:
            cal_4 = 5

        else:
            cal_4 = 0

        # 5ta pregunta
        # calcularCalificacionEscala(df)

        # 8va pregunta
        if df[qr.r8][i] == qr.r8a:
            cal_8 = 1

        elif df[qr.r8][i] == qr.r8b:
            cal_8 = 2

        elif df[qr.r8][i] == qr.r8c:
            cal_8 = 3

        elif df[qr.r8][i] == qr.r8d:
            cal_8 = 4

        elif df[qr.r8][i] == qr.r8e:
            cal_8 = 5

        else:
            cal_8 = 0

        # genero d1 con las calificaciones
        d1 = dict(
            [
                ("Token", df.loc[i, "Token"]),
                ("C1", cal_1),
                ("C2", cal_2),
                ("C3", cal_3),
                ("C4", cal_4),
                ("C5", cal_5),
                ("C8", cal_8),
            ]
        )

        # asigno la moda a un nuevo dataframe
        d2 = dict(
            [
                ("Token", df.loc[i, "Token"]),
                ("C1", cal_1),
                ("C2", cal_2),
                ("C3", cal_3),
                ("C4", cal_4),
                ("C5", cal_5),
                ("C8", cal_8),
                ("MODA_A", calculo.moda(d1)),
            ]
        )
        # print(i, "d2", d2)

        lista.append(d2)

    return lista

    # return d1

# %%
# función con un parámetro GESTION DE DATOS
def calcularCalificacionGestionDatos(df):
    # inicializar variables en 0 para que no guarden basura de pruebas anteriores
    lista = []
    # metodo para calcular las calificaciones, primera pregunta con su token , respuesta y calificacion asignada a la p1
    for i in range(len(df)):

        if df[qr.r9][i] == qr.r9a:
            cal_9 = 1

        elif df[qr.r9][i] == qr.r9b:
            cal_9 = 2

        elif df[qr.r9][i] == qr.r9c:
            cal_9 = 3

        elif df[qr.r9][i] == qr.r9d:
            cal_9 = 4

        elif df[qr.r9][i] == qr.r9e:
            cal_9 = 5

        else:
            cal_9 = 0

        # R11
        if df[qr.r11][i] == qr.r11a:
            cal_11 = 1

        elif df[qr.r11][i] == qr.r11b:
            cal_11 = 2

        elif df[qr.r11][i] == qr.r11c:
            cal_11 = 3

        elif df[qr.r11][i] == qr.r11d:
            cal_11 = 4

        elif df[qr.r11][i] == qr.r11e:
            cal_11 = 5

        else:
            cal_11 = 0

        # R12
        if df[qr.r12][i] == qr.r12a:
            cal_12 = 1

        elif df[qr.r12][i] == qr.r12b:
            cal_12 = 2

        elif df[qr.r12][i] == qr.r12c:
            cal_12 = 3

        elif df[qr.r12][i] == qr.r12d:
            cal_12 = 4

        elif df[qr.r12][i] == qr.r12e:
            cal_12 = 5

        else:
            cal_12 = 0

        # R14
        if df[qr.r14][i] == qr.r14a:
            cal_14 = 1

        elif df[qr.r14][i] == qr.r14b:
            cal_14 = 2

        elif df[qr.r14][i] == qr.r14c:
            cal_14 = 3

        elif df[qr.r14][i] == qr.r14d:
            cal_14 = 4

        elif df[qr.r14][i] == qr.r14e:
            cal_14 = 5

        else:
            cal_14 = 0

        # R15
        if df[qr.r15][i] == qr.r15a:
            cal_15 = 1

        elif df[qr.r15][i] == qr.r15b:
            cal_15 = 2

        elif df[qr.r15][i] == qr.r15c:
            cal_15 = 3

        elif df[qr.r15][i] == qr.r15d:
            cal_15 = 4

        elif df[qr.r15][i] == qr.r15e:
            cal_15 = 5

        else:
            cal_15 = 0

        # R16
        if df[qr.r16][i] == qr.r16a:
            cal_16 = 1

        elif df[qr.r16][i] == qr.r16b:
            cal_16 = 2

        elif df[qr.r16][i] == qr.r16c:
            cal_16 = 3

        elif df[qr.r16][i] == qr.r16d:
            cal_16 = 4

        elif df[qr.r16][i] == qr.r16e:
            cal_16 = 5

        else:
            cal_16 = 0

        # genero d1 con las calificaciones
        d1 = dict(
            [
                ("Token", df.loc[i, "Token"]),
                ("C9", cal_9),
                ("C11", cal_11),
                ("C12", cal_12),
                ("C14", cal_14),
                ("C15", cal_15),
                ("C16", cal_16),
            ]
        )

        # asigno la moda a un nuevo dataframe
        d2 = dict(
            [
                ("Token", df.loc[i, "Token"]),
                ("C9", cal_9),
                ("C11", cal_11),
                ("C12", cal_12),
                ("C14", cal_14),
                ("C15", cal_15),
                ("C16", cal_16),
                ("MODA_B", calculo.modaGestion(d1)),
            ]
        )

        # print(i, "d2", d2)

        lista.append(d2)

    return lista

# %%
# función con un parámetro
def calcularCalificaciones(r, df, ra, rb, rc, rd, re):
    # metodo para calcular las calificaciones, preguntas con su token , respuesta y calificacion asignada a la pregunta
    for i in range(len(df)):

        # primeraPregunta
        if df[r][i] == ra:
            cal = 1

        elif df[r][i] == rb:
            cal = 2

        elif df[r][i] == rc:
            cal = 3

        elif df[r][i] == rd:
            cal = 4

        elif df[r][i] == re:
            cal = 5

        else:
            cal = 0

        d2 = dict([("Token", df.loc[i, "Token"]), ("cal", cal)])
        # print(i, "datos", d2)

# %%
# calculo de calificaciones segun la rubrica pregunta 5
def calcularCalp5(cantsi):
    calificacion = 0
    if cantsi == 4:
        calificacion = 5
    elif cantsi == 3:
        calificacion = 4
    elif cantsi == 2:
        calificacion = 3
    elif cantsi == 1:
        calificacion = 2
    else:
        calificacion = 0

    return calificacion

# %%
# Calcular calificación pregunta 5 Escala
def calcularCalificacionEscala(df):
    # metodo para calcular las calificaciones, preguntas con su token , respuesta y calificacion asignada a la pregunta
    listap5 = []
    for i in range(len(df)):
        cantsi = 0
        # primeraPregunta
        if df[qr.r5a][i] == "Si":
            cantsi += 1

        if df[qr.r5b][i] == "Si":
            cantsi += 1

        if df[qr.r5c][i] == "Si":
            cantsi += 1

        if df[qr.r5d][i] == "Si":
            cantsi += 1

        dp5 = dict([("Token", df.loc[i, "Token"]), ("C5", calcularCalp5(cantsi))])

        listap5.append(dp5)

    return listap5

# %%
# pregunta 5 Coeficiente analitico 2da prueba
def calcularCalificacionp5(df):
    # metodo para calcular las calificaciones, preguntas con su token , respuesta y calificacion asignada a la pregunta

    for i in range(len(df)):
        cantsi = 0
        # primeraPregunta
        if df[qr.r5a][i] == "Si":
            cantsi += 1

        if df[qr.r5b][i] == "Si":
            cantsi += 1

        if df[qr.r5c][i] == "Si":
            cantsi += 1

        if df[qr.r5d][i] == "Si":
            cantsi += 1

        dp5 = dict([("Token", df.loc[i, "Token"]), ("C5", calcularCalp5(cantsi))])

        # print(dp5["C5"])
        # print(i, "C5: ", dp5["C5"])

        return dp5["C5"]
